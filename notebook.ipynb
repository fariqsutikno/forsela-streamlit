# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_lintas_angkatan = pd.read_csv("https://docs.google.com/spreadsheets/d/1Qctp9yKzecR4KGKTYsiKGZW2YOABkyZcMDzzpnS45vQ/export?format=csv&gid=944201584")

# %%
df_lintas_angkatan.head()
# Out:
#    id  No.                        Nama      Kelas       Angkatan  \
# 0   1    1        Abadan Ghazian Khair  [unknown]  30 [Alqatras]
# 1   2    1        Abdallah Nur Rachman        12A   31 [Barzada]
# 2   3    1          Abdulloh Al Fathin        12A   32 [Szarvas]
# 3   4    2                  Abdul Barr  [unknown]  30 [Alqatras]
# 4   5    2  Abdurrahman Naufal Chandra        12A   31 [Barzada]
#
#          Status     Kategori Umum/Agama Tahun Masuk Kota/Negara  \
# 0  Studi Lanjut  Luar Negeri      Agama        2022    Yordania
# 1  Studi Lanjut        LIPIA      Agama        2023     Jakarta
# 2  Studi Lanjut          PTS  [unknown]        2023    Banyumas
# 3  Studi Lanjut  Luar Negeri      Agama        2024       Mesir
# 4  Studi Lanjut          PTS      Agama        2023      Jember
#
#                            Universitas                Jurusan    Sarjana  \
# 0                   Yarmouk University          Ekonomi Islam    Sarjana
# ...
